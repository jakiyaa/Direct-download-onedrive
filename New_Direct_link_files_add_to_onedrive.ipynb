# %% [markdown]
# <a href="https://colab.research.google.com/github/jakiya99/Direct-download-onedrive/blob/main/New_Direct_link_files_add_to_onedrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⎝乡direct links <font color='greenr'>upload </font> to  <font color='lightblue'>onedrive</font>  </font> <img src='https://www.gb-advisors.com/wp-content/uploads/2020/03/OneDrive-Logo.png' height="90" /> BY'-  <font color='red'> ツ  jคK¡ץA   ⎝⎝乡 </font>

# %% [markdown]
# # <font color='pink'> Tools  </font>
#
#
#  *   <font color='yellow'> Rclone </font> - download rclone your operating system download link= https://rclone.org/downloads/
#  *   <font color='yellow'> Onedrive Account  </font> (personal,business both working) no account? just signup https://signup.live.com/

# %% [markdown]
# # 1.Install  <img src='https://biplobsd.github.io/RLabClone/img/title_rclonelab.svg' height="45" alt="RcloneLab"/>

# %%
# !wget https://downloads.rclone.org/v1.52.1/rclone-v1.52.1-linux-amd64.deb
# !apt install ./rclone-v1.52.1-linux-amd64.deb

# %% [markdown]
# # 2.Rclone </font> <font color='orange'>Authenticate One Drive </font> <img src='https://biplobsd.github.io/RLabClone/img/title_rclonelab.svg' height="45" alt="RcloneLab"/>

# %%
# !rclone config      #add your onedrive

# %% [markdown]
# <img src='https://cdn.vox-cdn.com/uploads/chorus_asset/file/12410821/Confused_Ice_Cube.0.gif' height="150" />
#
# #</font> <font color='red'> CAN'T CONFIG?  </font>  follow this,
#
# 1.type </font> <font color='red'>"n"  </font>        - new remote
#
# 2.type</font> <font color='red'> onedrive </font> -name
#
# 3.type </font> <font color='red'>"23"  </font>  -storage
#
# 4.press </font> <font color='red'> enter </font>      -client id
#
# 5.press </font> <font color='red'>enter </font>      -client secret
#
# 6.type </font> <font color='red'>"n"  </font>     -edit advanced no
#
# 7.type</font> <font color='red'>"n"  </font>      -auto config no
#
# 8.</font> <font color='gree'>get rclone Authenticate One Drive code and paste and press enter </font> </font> <font color='red'>HOW TO GET CODE? </font> see details= https://github.com/jakiya99/Torrent-to-Onedrive/blob/main/rclone%20config/authenticate%20onedrive%20rclone.md
#
# 9.type</font> <font color='red'>"1"  </font>'
#
# 10.type'</font> <font color='red'>"0"  </font>
#
# 11.type</font> <font color='red'>"y"  </font>
#
# 12.type</font> <font color='red'>"y"  </font>
#
# 13.type  </font> <font color='red'>"q"  </font>

# %% [markdown]
# # 3.Rclone<font color='yellow'>  Mount one drive

# %%
# !mkdir onedrive
# !nohup rclone --vfs-cache-mode writes mount onedrive: ./onedrive &
# Out:
# nohup: appending output to 'nohup.out'
# nohup: failed to run command 'rclone': No such file or directory

# %%
# !ls ./onedrive    #after sucessfully mounted onedrive then show your onedrive folders and files

# %% [markdown]
# #4.Paste <font color='orange'> Direct download link  <img src='https://iconarchive.com/download/i99352/dtafalonso/android-lollipop/Downloads.ico' height="100" alt="RcloneLab"/>

# %%
# !wget -P ./onedrive/downloads "https://nodejs.org/dist/v14.16.0/node-v14.16.0-x64.msi"        #example=  !wget -P downloads https://abcd123.com/music.mp3          

                          #!wget -P downloads --user="type your username here" --password="type password here" 'paste link here'

# %% [markdown]
# not downloding? <font color='red'>error 403 Foribedden</font> or <font color='red'>error500  </font> links try this,
#
# !wget -P downloads --user="type your username here" --password="type password here" 'paste link here'

# %% [markdown]
# <img src='https://cdn.dribbble.com/users/2760451/screenshots/5667639/file-transfer.gif' height="200" />

# %% [markdown]
# <img src='https://cdn.freelogovectors.net/wp-content/uploads/2019/02/winrar_logo.png' height="90" /> #Extra -  need downloaded <font color='yellow'> zip files</font>  to  <font color='yellow'> unzip? </font>

# %%
# !mkdir unzipedflies

import zipfile
with zipfile.ZipFile("[ FreeCourseWeb.com ] Udemy - The Ultimate Dark Web, Anonymity, Privacy & Security Course.zip","r") as zip_ref:            
    zip_ref.extractall("unzipedflies")  

    #example        
    #import zipfile
    #with zipfile.ZipFile("setup123.zip","r") as zip_ref:
    #zip_ref.extractall("unzipedflies")

# %%
# !rsync -ah --progress unzipedflies/ onedrive/      #copy unzip files to onedrive
